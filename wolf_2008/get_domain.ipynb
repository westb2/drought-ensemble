# %%
import config as config
import sys


sys.path.append("../")
from get_domain import get_domain

# %%
get_domain(config)
# Out:
# POTOMAC_1999_to_1999_1999_to_1999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_domain(config)
#
# File ~/Documents/GitHub/drought-ensemble/wolf/../get_domain.py:46, in get_domain(config)
#      44 # load your preferred template runscript
#      45 reference_run = st.get_template_runscript(grid, "transient", "solid", pf_out_dir)
# ---> 46 ij_bounds, mask = st.define_huc_domain(hucs=hucs, grid=grid)
#      47 os.environ["PARFLOW_DIR"] = "/Users/ben/parflow_installation/parflow"
#      48 mask_solid_paths = st.write_mask_solid(mask=mask, grid=grid, write_dir=static_write_dir)
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/subsettools/domain.py:99, in define_huc_domain(hucs, grid)
#      92 hucs = [int(huc) for huc in hucs]
#      93 options = {
#      94     "dataset": "huc_mapping",
#      95     "grid": grid,
# ...
