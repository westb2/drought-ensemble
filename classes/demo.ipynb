# %%
import sys
import os

from RunOutputReader import RunOutputReader
from Run import Run
from Domain import Domain

# %%
domain = Domain(config_file="/Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/config.ini", TESTING=True)
domain.get_domain()
# Out:
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_dry
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_wet
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_average

# %%
run = Run(sequence="simple_test.json", domain=domain, output_root="/Users/ben/Desktop/drought-ensemble")
run.run_full_sequence()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 run = Run(sequence="simple_test.json", domain=domain, output_root="/Users/ben/Desktop/drought-ensemble")
#       2 run.run_full_sequence()
#
# File ~/Documents/GitHub/drought-ensemble/classes/Run.py:33, in Run.__init__(self, sequence, domain, output_root)
#      31 self.number_of_years = len(self.sequence["years"])
#      32 self.run_dir = self.get_run_folder()
# ---> 33 self.output_reader = RunOutputReader(self)
#
# File ~/Documents/GitHub/drought-ensemble/classes/RunOutputReader.py:18, in RunOutputReader.__init__(self, run)
#      16 def __init__(self, run):
#      17     self.run = run
# ---> 18     data_accessor = self.get_data_accessor(self.run.domain.get_base_run_folder("average"))
#      19     self.domain_attributes = {}
#      21     self.domain_attributes["mask"] = data_accessor.mask
#
# File ~/Documents/GitHub/drought-ensemble/classes/RunOutputReader.py:38, in RunOutputReader.get_data_accessor(self, run_dir)
#      36 def get_data_accessor(self, run_dir):
#      37     run_dir = self.run.get_output_folders()[0]
# ---> 38     data_accessor = pf.Run.from_definition(f'{run_dir}/run.yaml').data_accessor
#      39     shutil.copyfile(f'{run_dir}/mannings.pfb', f'{run_dir}/run.out.mannings.pfb')
#      40     return data_accessor
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/parflow/tools/core.py:315, in Run.from_definition(cls, file_path)
#     313 new_run = cls(name, file_path)
#     314 kwargs = {ext_map[ext]: file_path}
# --> 315 new_run.pfset(silence_if_undefined=True, **kwargs)
#     317 # Try to solve order sensitive property settings
#     318 while "_pfstore_" in new_run.__dict__:
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/parflow/tools/database/core.py:626, in PFDBObj.pfset(self, key, value, yaml_file, yaml_content, pfidb_file, hierarchical_map, flat_map, exit_if_undefined, silence_if_undefined)
#     611 """
#     612 Allow to define any parflow key so it can be exported.
#     613 Many formats are supported:
#    (...)
#     623         using the current PFDBObj as root.
#     624 """
#     625 if yaml_file:
# --> 626     yaml_content = get_text_file_content(yaml_file)
#     628 if yaml_content:
#     629     hierarchical_map = yaml.safe_load(yaml_content)
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/parflow/tools/fs.py:81, in get_text_file_content(file_path)
#      79 full_path = Path(get_absolute_path(file_path))
#      80 if not full_path.exists():
# ---> 81     raise Exception(f"{str(full_path)} does not exist!")
#      83 return full_path.read_text()
#
# Exception: /Users/ben/Desktop/drought-ensemble/raw_runs/fc2a5b1d5cf4b8279c7d6a98de84df89f0bc21961f7fd18bac11228fec55ac9c/run.yaml does not exist!

# %%
run_output_reader = RunOutputReader(run)
data = run_output_reader.read_output(save_to_file=True)
# Out:
# Solver: Field BinaryOutDir is not part of the expected schema <class 'parflow.tools.database.generated.Solver'>
# : Field run_dir is not part of the expected schema <class 'parflow.tools.core.Run'>
# xarray.Dataset {
# dimensions:
# 	time = 96 ;
# 	z = 10 ;
# 	y = 41 ;
# 	x = 78 ;
#
# variables:
# 	int64 time(time) ;
# 	int64 z(z) ;
# 	int64 y(y) ;
# 	int64 x(x) ;
# 	float64 pressure(time, z, y, x) ;
# 	float64 saturation(time, z, y, x) ;
# 	float64 mask(z, y, x) ;
# 	float64 mannings(z, y, x) ;
#
# // global attributes:
# 	:sequence_name = simple_test ;
# }Saved condensed output to /Users/ben/Documents/GitHub/drought-ensemble/processed_full_runs/simple_test

# %%
data.pressure.isel(time=25, z=0).plot()
