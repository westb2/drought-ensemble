# %%
import sys
import os

from RunOutputReader import RunOutputReader
from Run import Run
from Domain import Domain

# %%
domain = Domain(config_file="/Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/config.ini", TESTING=True)
domain.get_domain()
# Out:
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_dry
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_wet
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_average

# %%
run = Run(sequence="simple_test.json", domain=domain)
run.run_full_sequence()
# Out:
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_dry
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_wet
# /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/inputs/wolf_test_average
# Year 0 of the run already exists in /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/raw_runs/fc2a5b1d5cf4b8279c7d6a98de84df89f0bc21961f7fd18bac11228fec55ac9c
# Year 1 of the run already exists in /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/raw_runs/ed471bc46c1a7fe12cf9d789aa2dc6b8c7791990e89303ef8e539ed7146fcdc4
# Year 2 of the run already exists in /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/raw_runs/f3fedf9a926fb1b02bc979eef8ea986cf7c2b0d276e99826cbac34c16e630ab6
# Year 3 of the run already exists in /Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/raw_runs/7d99045cbfef8feaf0d96167c0d1436ba999f6d1aaf4cbf9f7abbfd4f8590a81
# Running average_0.0_False_dry_0.0_False_wet_0.0_False_average_0.0_False

# %%
run_output_reader = RunOutputReader(run)
data = run_output_reader.read_output(save_to_file=True)
# Out:
# Solver: Field BinaryOutDir is not part of the expected schema <class 'parflow.tools.database.generated.Solver'>
# : Field run_dir is not part of the expected schema <class 'parflow.tools.core.Run'>
# xarray.Dataset {
# dimensions:
# 	time = 48 ;
# 	z = 10 ;
# 	y = 41 ;
# 	x = 78 ;
#
# variables:
# 	int64 time(time) ;
# 	int64 z(z) ;
# 	int64 y(y) ;
# 	int64 x(x) ;
# 	float64 pressure(time, z, y, x) ;
# 	float64 saturation(time, z, y, x) ;
# 	float64 mask(z, y, x) ;
# 	float64 mannings(z, y, x) ;
#
# // global attributes:
# 	:sequence_name = simple_test ;
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/processed_full_runs/simple_test/run.out.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '322ada88-d785-4701-9428-6f0797cc2740']
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 2
#       1 run_output_reader = RunOutputReader(run)
# ----> 2 data = run_output_reader.read_output(save_to_file=True)
#
# File ~/Documents/GitHub/drought-ensemble/classes/RunOutputReader.py:84, in RunOutputReader.read_output(self, save_to_file)
#      82     os.makedirs(f'{self.run.domain.directory}/processed_full_runs', exist_ok=True)
#      83     output_path = f'{self.run.domain.directory}/processed_full_runs/{self.run.sequence["name"]}'
# ---> 84     data_array.to_netcdf(os.path.join(output_path, "run.out.nc"))
#      85     json.dump(self.run.sequence, open(os.path.join(output_path, "sequence.json"), "w"))
#      86 return data_array
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/core/dataset.py:2346, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf, auto_complex)
#    2343     encoding = {}
#    2344 from xarray.backends.api import to_netcdf
# -> 2346 return to_netcdf(  # type: ignore[return-value]  # mypy cannot resolve the overloads:(
#    2347     self,
#    2348     path,
#    2349     mode=mode,
#    2350     format=format,
#    2351     group=group,
#    2352     engine=engine,
#    2353     encoding=encoding,
#    2354     unlimited_dims=unlimited_dims,
#    2355     compute=compute,
#    2356     multifile=False,
#    2357     invalid_netcdf=invalid_netcdf,
#    2358     auto_complex=auto_complex,
#    2359 )
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/api.py:1855, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf, auto_complex)
#    1852 if auto_complex is not None:
#    1853     kwargs["auto_complex"] = auto_complex
# -> 1855 store = store_open(target, mode, format, group, **kwargs)
#    1857 if unlimited_dims is None:
#    1858     unlimited_dims = dataset.encoding.get("unlimited_dims", None)
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:453, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, auto_complex, lock, lock_maker, autoclose)
#     449     kwargs["auto_complex"] = auto_complex
#     450 manager = CachingFileManager(
#     451     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     452 )
# --> 453 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:394, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     392 self._group = group
#     393 self._mode = mode
# --> 394 self.format = self.ds.data_model
#     395 self._filename = self.ds.filepath()
#     396 self.is_remote = is_remote_uri(self._filename)
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:462, in NetCDF4DataStore.ds(self)
#     460 @property
#     461 def ds(self):
# --> 462     return self._acquire()
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:456, in NetCDF4DataStore._acquire(self, needs_lock)
#     455 def _acquire(self, needs_lock=True):
# --> 456     with self._manager.acquire_context(needs_lock) as root:
#     457         ds = _nc4_require_group(root, self._group, self._mode)
#     458     return ds
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /opt/homebrew/anaconda3/envs/test-env/lib/python3.11/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2469, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2028, in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: '/Users/ben/Documents/GitHub/drought-ensemble/domains/wolf_test/testing/processed_full_runs/simple_test/run.out.nc'

# %%
data.pressure.isel(time=25, z=0).plot()
